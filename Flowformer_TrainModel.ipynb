# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import numpy as np
from tqdm import tqdm
from xlstm.xlstm_block_stack import xLSTMBlockStack, xLSTMBlockStackConfig
from dacite import from_dict, Config as DaciteConfig
from omegaconf import OmegaConf
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

from math import gcd
from functools import reduce
import torch.nn as nn
import numpy as np
from pandas import read_csv
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import random

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
torch.tensor([1.0, 2.0]).cuda()
# Out:
# 2.7.1+cu128
# True
# NVIDIA GeForce RTX 5070 Ti
# 12.8
# tensor([1., 2.], device='cuda:0')

# %%
def ReadExcel(excelpath: str):
    DF = pd.read_excel(excelpath)
    Values = DF.iloc[:, 1:].values 
    
    Values = Values.astype('float32') 
    print(Values.shape)
    return Values

# %%
Vel_1_23_1200 = ReadExcel(r'D:\0DATA\NHRI\1、23_1200.xlsx')
Vel_2_32_300 = ReadExcel(r'D:\0DATA\NHRI\2、32_300.xlsx')
Vel_3_32_160 = ReadExcel(r'D:\0DATA\NHRI\3、32_160.xlsx')
Vel_4_32_sametime = ReadExcel(r'D:\0DATA\NHRI\4、32_sametime.xlsx')
Vel_5_23_160 = ReadExcel(r'D:\0DATA\NHRI\5、23_160.xlsx')
Vel_6_23_300 = ReadExcel(r'D:\0DATA\NHRI\6、23_300.xlsx')
Vel_7_23_600 = ReadExcel(r'D:\0DATA\NHRI\7、23_600.xlsx')
Vel_8_32_600 = ReadExcel(r'D:\0DATA\NHRI\8、32_600.xlsx')
Vel_9_23_900 = ReadExcel(r'D:\0DATA\NHRI\9、23_900.xlsx')
Vel_10_32_900 = ReadExcel(r'D:\0DATA\NHRI\10、32_900.xlsx')
Vel_11_32_1200 = ReadExcel(r'D:\0DATA\NHRI\11、32_1200.xlsx')
Vel_12_23_1500 = ReadExcel(r'D:\0DATA\NHRI\12、23_1500.xlsx')
Vel_13_32_1500 = ReadExcel(r'D:\0DATA\NHRI\13、32_1500.xlsx')
Vel_14_23_450 = ReadExcel(r'D:\0DATA\NHRI\14、23_450.xlsx')
Vel_15_32_450 = ReadExcel(r'D:\0DATA\NHRI\15、32_450.xlsx')
Vel_16_23_750 = ReadExcel(r'D:\0DATA\NHRI\16、23_750.xlsx')
Vel_17_32_750 = ReadExcel(r'D:\0DATA\NHRI\17、32_750.xlsx')
Vel_18_23_1050 = ReadExcel(r'D:\0DATA\NHRI\18、23_1050.xlsx')
Vel_19_32_1050 = ReadExcel(r'D:\0DATA\NHRI\19、32_1050.xlsx')
Vel_20_23_1350 = ReadExcel(r'D:\0DATA\NHRI\20、23_1350.xlsx')
Vel_21_32_1350 = ReadExcel(r'D:\0DATA\NHRI\21、32_1350.xlsx')
Vel_22_32_sametime = ReadExcel(r'D:\0DATA\NHRI\22、32_sametime.xlsx')
# Out:
# (1653, 185)
# (1057, 185)
# (1040, 185)
# (762, 185)
# (739, 185)
# (687, 185)
# (1056, 185)
# (1392, 185)
# (1353, 185)
# (1646, 185)
# (1988, 185)
# (2009, 185)
# (2353, 185)
# (910, 185)
# (1279, 185)
# (1216, 185)
# (1671, 185)
# (1508, 185)
# (1853, 185)
# (1868, 185)
# (1827, 185)
# (836, 185)

# %%
nums = [Vel_1_23_1200.shape[0], Vel_2_32_300.shape[0], Vel_3_32_160.shape[0], Vel_4_32_sametime.shape[0], Vel_5_23_160.shape[0], Vel_6_23_300.shape[0],
        Vel_7_23_600.shape[0], Vel_8_32_600.shape[0], Vel_9_23_900.shape[0], Vel_10_32_900.shape[0], Vel_11_32_1200.shape[0], Vel_12_23_1500.shape[0],
        Vel_13_32_1500.shape[0], Vel_14_23_450.shape[0], Vel_15_32_450.shape[0], Vel_16_23_750.shape[0], Vel_17_32_750.shape[0], Vel_18_23_1050.shape[0],
        Vel_19_32_1050.shape[0], Vel_20_23_1350.shape[0], Vel_21_32_1350.shape[0], Vel_22_32_sametime.shape[0]]
RowNum = sum(nums)
print(f"总行数为 ： {RowNum}")
# Out:
# [1653, 1057, 1040, 762, 739, 687, 1056, 1392, 1353, 1646, 1988, 2009, 2353, 910, 1279, 1216, 1671, 1508, 1853, 1868, 1827, 836] 的所有公约数是: [1]
# 总行数为 ： 30703

# %%
import random

all_conditions = [Vel_1_23_1200, Vel_2_32_300, Vel_3_32_160, Vel_4_32_sametime, Vel_5_23_160, Vel_6_23_300, Vel_7_23_600, Vel_8_32_600, Vel_9_23_900, Vel_10_32_900,
                  Vel_11_32_1200, Vel_12_23_1500, Vel_13_32_1500, Vel_14_23_450,  Vel_15_32_450, Vel_16_23_750, Vel_17_32_750, Vel_18_23_1050, Vel_19_32_1050,
                  Vel_20_23_1350, Vel_21_32_1350, Vel_22_32_sametime]


train_raw = [Vel_1_23_1200, Vel_2_32_300, Vel_3_32_160, Vel_4_32_sametime, Vel_5_23_160, Vel_6_23_300, Vel_8_32_600, Vel_9_23_900, Vel_10_32_900,
             Vel_11_32_1200, Vel_12_23_1500, Vel_14_23_450,  Vel_15_32_450, Vel_16_23_750, Vel_19_32_1050,
             Vel_20_23_1350, Vel_21_32_1350]
test_raw = [Vel_7_23_600, Vel_13_32_1500, Vel_17_32_750, Vel_18_23_1050, Vel_22_32_sametime]    

print("len(test_raw) = ", len(test_raw))
print("len(train_raw) = ", len(train_raw))
print(len(test_raw) + len(train_raw))
# Out:
# len(test_raw) =  5
# len(train_raw) =  17
# 22

# %%
hist_step = 60   
pred_step = 1    
input_channel = 3   
input_data_num = hist_step * input_channel
output_channel = 5

# %%
def extract_input_matrix(data_list):
    X_all = np.vstack([d[:, :input_data_num] for d in data_list])  # (N_total, 120)
    X_reshaped = X_all.reshape(-1, hist_step, input_channel)               # (N_total, 40, 3)
    return X_reshaped.reshape(-1, input_channel)                    # → (N_total*40, 3)



def extract_output_matrix(data_list):
    return np.vstack([d[:, input_data_num:] for d in data_list])  # (N_total, 54)

X_input_for_scaler = extract_input_matrix(train_raw)
Y_output_for_scaler = extract_output_matrix(train_raw)

print(X_input_for_scaler.shape)
print(Y_output_for_scaler.shape)
# Out:
# (1396740, 3)
# (23279, 5)

# %%
scaler_input = MinMaxScaler()
scaler_output = MinMaxScaler()

scaler_input.fit(X_input_for_scaler)
scaler_output.fit(Y_output_for_scaler)
# Out:
# MinMaxScaler()

# %%
def normalize_condition_data(data_list):
    normalized = []
    for d in data_list:
        x = d[:, :input_data_num].reshape(-1, hist_step, input_channel)
        x = scaler_input.transform(x.reshape(-1, input_channel)).reshape(-1, hist_step, input_channel)
        y = scaler_output.transform(d[:, input_data_num:])
        normalized.append((x, y))
    return normalized

train_data = normalize_condition_data(train_raw)



test_data = []
for d in test_raw:
    x = d[:, :input_data_num].reshape(-1, hist_step, input_channel)
    x = scaler_input.transform(x.reshape(-1, input_channel)).reshape(-1, hist_step, input_channel)
    y = scaler_output.transform(d[:, input_data_num:])
    test_data.append((x, y))

# %%
print(len(train_data))
print(len(test_data))
print(type(train_data[0]))
print(type(test_data[0]))
# Out:
# 17
# 5
# <class 'tuple'>
# <class 'tuple'>

# %%
class ConditionDataset(Dataset):
    def __init__(self, x_array, y_array):
        self.X = torch.tensor(x_array, dtype=torch.float32)  # (N, 40, 3)
        self.Y = torch.tensor(y_array, dtype=torch.float32)  # (N, 54)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]
    
def build_data_loaders(data, batch_size):
    loaders = []
    for x, y in data:
        ds = ConditionDataset(x, y)
        dl = DataLoader(ds, batch_size=batch_size, shuffle=False, drop_last=False)
        loaders.append(dl)
    return loaders


BatchSize= 64

train_loaders = build_data_loaders(train_data, batch_size=BatchSize) 
test_loader = build_data_loaders(test_data, batch_size=BatchSize)  

print(len(train_loaders))
print(len(test_loader))
# Out:
# 17
# 5

# %%
def safe_mape(y_true, y_pred, epsilon=1e-8, threshold=0.01):
    
    
    y_pred = y_pred.to(y_true.device)
    
    
    mask = torch.abs(y_true) > threshold
    
    
    if mask.sum() == 0:
        return torch.tensor(float('nan'), device=y_true.device)
    
    
    ape = torch.abs((y_true[mask] - y_pred[mask]) / (y_true[mask] + epsilon))
    
    return torch.mean(ape) * 100

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
from model.Flowformer import Model as Flowformer
import torch
import torch.nn as nn

class Config:
    def __init__(self):
        self.seq_len = 60
        self.pred_len = 1
        self.d_model = 256 #64
        self.d_state = 16
        self.d_ff = 256 #128
        self.e_layers = 2
        self.d_layers = 1
        self.dropout = 0.32
        self.embed = 'timeF'
        self.freq = 'h'
        self.activation = 'gelu'
        self.output_attention = False
        self.use_norm = False
        self.class_strategy = 'cls'
        self.channel_independence = False
        self.enc_in = 3
        self.dec_in = 3
        self.c_out = 5
        self.factor = 1
        self.n_heads = 8 #8
        self.distil = True

args = Config()
args.pred_len = 1
args.enc_in = 3
args.dec_in = 3
args.c_out = 5

args.device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = Flowformer(args).to(args.device)
print("args.device = ", args.device)
print(model)


# Loss function and optimizer
num_epochs = 10000
epsilon = 0.0001
max_grad_norm = 1.0 
criterion = nn.MSELoss()

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, eps=epsilon, weight_decay=1e-5) # lr=0.0001
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, threshold=1e-4, cooldown=2, min_lr=1e-6) 

trainloss_list = []
testloss_list = []
trainMAPE_list = []
testMAPE_list = []
import time
start_time = time.time()

save_dir = r'D:\0DATA\NHRI\7、Flowformer'

# Training loop
loss_hist = np.zeros(num_epochs)
test_loss_hist = np.zeros(num_epochs)
test_loss_threshold = 0.09
best_test_loss = test_loss_threshold


for epoch in range(num_epochs):
    model.train() 
    for loader in train_loaders:
        for x, y in loader:
            x = x.to(args.device)
            y = y.to(args.device)

            B, L, D = x.shape
            x_mark_enc = torch.zeros(B, L, 4).to(x.device)
            x_dec = torch.zeros(B, args.pred_len, D).to(x.device)
            x_mark_dec = torch.zeros(B, args.pred_len, 4).to(x.device)

            optimizer.zero_grad()
            out = model(x, x_mark_enc, x_dec, x_mark_dec)  # [B, 1, 54]
            out = out[:, -1, :]  # [B, 54]
            loss = criterion(out, y)
            trainloss_list.append(loss.item())
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)  
            optimizer.step()

    model.eval()  
    with torch.no_grad():   
        for loader in test_loader:
            for x, y in loader:
                x = x.to(args.device)
                y = y.to(args.device)

                B, L, D = x.shape
                x_mark_enc = torch.zeros(B, L, 4).to(x.device)
                x_dec = torch.zeros(B, args.pred_len, D).to(x.device)
                x_mark_dec = torch.zeros(B, args.pred_len, 4).to(x.device)

                out = model(x, x_mark_enc, x_dec, x_mark_dec)
                out = out[:, -1, :]  # [B, 54]
                loss = criterion(out, y)
                testloss_list.append(loss.item())
            
                
                testmape = safe_mape(out, y)
                testMAPE_list.append(testmape.item())
    
    
    ave_train_loss = np.mean(trainloss_list)
    ave_test_loss = np.mean(testloss_list)
    ave_test_mape = np.mean(testMAPE_list)
    trainloss_list = []
    testloss_list = []

    scheduler.step(ave_test_loss) 


    if(ave_test_loss < best_test_loss):   
        torch.save(model, os.path.join(save_dir, f'epoch.{epoch:05d}-test_loss.{ave_test_loss:.5f}-test_MAPE.{ave_test_mape:.5f}.pth'))
        best_test_loss = ave_test_loss
        print(f'Epoch [{epoch}/{num_epochs}], Train Loss: {ave_train_loss.item():.5f}, Test Loss: {ave_test_loss.item():.5f}, Test MAPE: {ave_test_mape.item():.5f}%', '  -- Model saved')   
    elif((epoch % 100) == 0):
        torch.save(model, os.path.join(save_dir, f'epoch.{epoch:05d}-test_loss.{ave_test_loss:.5f}-test_MAPE.{ave_test_mape:.5f}.pth'))
        print(f'Epoch [{epoch}/{num_epochs}], Train Loss: {ave_train_loss.item():.5f}, Test Loss: {ave_test_loss.item():.5f}, Test MAPE: {ave_test_mape.item():.5f}%', '  -- Model saved')
    else:
        print(f'Epoch [{epoch}/{num_epochs}], Train Loss: {ave_train_loss.item():.5f}, Test Loss: {ave_test_loss.item():.5f}, Test MAPE: {ave_test_mape.item():.5f}%')
       
    loss_hist[epoch] = ave_train_loss.item()
    test_loss_hist[epoch] = ave_test_loss.item()
    
    
torch.save(model, os.path.join(save_dir, f'epoch.{epoch:05d}-val_loss.{ave_test_loss:.5f}-val_MAPE.{ave_test_mape:.5f}.pth'))       
print("Training complete **************************")
training_time = time.time() - start_time
print("Training time: {} ************************".format(training_time))
print(" ")


csv_path = r'D:\0DATA\NHRI\7、Flowformer\Flowformer Train process.csv'
np.savetxt(csv_path, np.column_stack((loss_hist, test_loss_hist)), delimiter=",", header="TrainLoss,TestLoss", comments='')
# Out:
# args.device =  cuda
# Model(
#   (enc_embedding): DataEmbedding(
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(3, 256, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (temporal_embedding): TimeFeatureEmbedding(
#       (embed): Linear(in_features=4, out_features=256, bias=False)
#     )
#     (dropout): Dropout(p=0.32, inplace=False)
#   )
#   (encoder): Encoder(
#     (attn_layers): ModuleList(
#       (0-1): 2 x EncoderLayer(
#         (attention): AttentionLayer(
#           (inner_attention): FlowAttention(
#             (dropout): Dropout(p=0.32, inplace=False)
#           )
#           (query_projection): Linear(in_features=256, out_features=256, bias=True)
#           (key_projection): Linear(in_features=256, out_features=256, bias=True)
#           (value_projection): Linear(in_features=256, out_features=256, bias=True)
#           (out_projection): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (conv1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.32, inplace=False)
#       )
#     )
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (dec_embedding): DataEmbedding(
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(3, 256, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (temporal_embedding): TimeFeatureEmbedding(
#       (embed): Linear(in_features=4, out_features=256, bias=False)
#     )
#     (dropout): Dropout(p=0.32, inplace=False)
#   )
#   (decoder): Decoder(
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attention): AttentionLayer(
#           (inner_attention): FullAttention(
#             (dropout): Dropout(p=0.32, inplace=False)
#           )
#           (query_projection): Linear(in_features=256, out_features=256, bias=True)
#           (key_projection): Linear(in_features=256, out_features=256, bias=True)
#           (value_projection): Linear(in_features=256, out_features=256, bias=True)
#           (out_projection): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (cross_attention): AttentionLayer(
#           (inner_attention): FullAttention(
#             (dropout): Dropout(p=0.32, inplace=False)
#           )
#           (query_projection): Linear(in_features=256, out_features=256, bias=True)
#           (key_projection): Linear(in_features=256, out_features=256, bias=True)
#           (value_projection): Linear(in_features=256, out_features=256, bias=True)
#           (out_projection): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (conv1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.32, inplace=False)
#       )
#     )
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (projection): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# Epoch [0/10000], Train Loss: 0.07321, Test Loss: 0.03619, Test MAPE: 17.67409%   -- Model saved
# Epoch [1/10000], Train Loss: 0.03123, Test Loss: 0.05557, Test MAPE: 19.04893%
# Epoch [2/10000], Train Loss: 0.03108, Test Loss: 0.04986, Test MAPE: 19.39071%
# Epoch [3/10000], Train Loss: 0.02695, Test Loss: 0.03476, Test MAPE: 19.51733%   -- Model saved
# Epoch [4/10000], Train Loss: 0.02128, Test Loss: 0.07517, Test MAPE: 23.35905%
# Epoch [5/10000], Train Loss: 0.02137, Test Loss: 0.01779, Test MAPE: 21.92770%   -- Model saved
# Epoch [6/10000], Train Loss: 0.01942, Test Loss: 0.01517, Test MAPE: 20.75908%   -- Model saved
# Epoch [7/10000], Train Loss: 0.02066, Test Loss: 0.01107, Test MAPE: 19.50916%   -- Model saved
10000], Train Loss: 0.01153, Test Loss: 0.00418, Test MAPE: 8.73344%
# Epoch [575/10000], Train Loss: 0.01150, Test Loss: 0.00418, Test MAPE: 8.73255%
# Epoch [576/10000], Train Loss: 0.01152, Test Loss: 0.00417, Test MAPE: 8.73165%
# Epoch [577/10000], Train Loss: 0.01148, Test Loss: 0.00418, Test MAPE: 8.73076%
# Epoch [578/10000], Train Loss: 0.01152, Test Loss: 0.00418, Test MAPE: 8.72987%
# Epoch [579/10000], Train Loss: 0.01148, Test Loss: 0.00418, Test MAPE: 8.72898%
# Epoch [580/10000], Train Loss: 0.01153, Test Loss: 0.00418, Test MAPE: 8.72812%
# Epoch [581/10000], Train Loss: 0.01153, Test Loss: 0.00418, Test MAPE: 8.72723%
# Epoch [582/10000], Train Loss: 0.01151, Test Loss: 0.00418, Test MAPE: 8.72637%
# Epoch [583/10000], Train Loss: 0.01154, Test Loss: 0.00418, Test MAPE: 8.72550%
# Epoch [584/10000], Train Loss: 0.01151, Test Loss: 0.00418, Test MAPE: 8.72463%
# Epoch [585/10000], Train Loss: 0.01155, Test Loss: 0.00418, Test MAPE: 8.72377%
# Epoch [586/10000], Train Loss: 0.01147, Test Loss: 0.00418, Test MAPE: 8.72293%
# Epoch [587/10000], Train Loss: 0.01155, Test Loss: 0.00418, Test MAPE: 8.72208%
# Epoch [588/10000], Train Loss: 0.01154, Test Loss: 0.00418, Test MAPE: 8.72122%
# Epoch [589/10000], Train Loss: 0.01152, Test Loss: 0.00418, Test MAPE: 8.72038%
# Epoch [590/10000], Train Loss: 0.01154, Test Loss: 0.00418, Test MAPE: 8.71952%
# Epoch [591/10000], Train Loss: 0.01152, Test Loss: 0.00418, Test MAPE: 8.71867%
# Epoch [592/10000], Train Loss: 0.01151, Test Loss: 0.00418, Test MAPE: 8.71781%
# Epoch [593/10000], Train Loss: 0.01153, Test Loss: 0.00418, Test MAPE: 8.71696%
# Epoch [594/10000], Train Loss: 0.01150, Test Loss: 0.00418, Test MAPE: 8.71611%
# Epoch [595/10000], Train Loss: 0.01155, Test Loss: 0.00418, Test MAPE: 8.71528%
# Epoch [596/10000], Train Loss: 0.01148, Test Loss: 0.00418, Test MAPE: 8.71445%
# Epoch [597/10000], Train Loss: 0.01148, Test Loss: 0.00418, Test MAPE: 8.71362%
# Epoch [598/10000], Train Loss: 0.01148, Test Loss: 0.00417, Test MAPE: 8.71277%
# Epoch [599/10000], Train Loss: 0.01152, Test Loss: 0.00418, Test MAPE: 8.71196%
# Epoch [600/10000], Train Loss: 0.01148, Test Loss: 0.00418, Test MAPE: 8.71112%   -- Model saved
# Epoch [601/10000], Train Loss: 0.01150, Test Loss: 0.00418, Test MAPE: 8.71028%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 84
#      81 y = y.to(args.device)
#      83 B, L, D = x.shape
# ---> 84 x_mark_enc = torch.zeros(B, L, 4).to(x.device)
#      85 x_dec = torch.zeros(B, args.pred_len, D).to(x.device)
#      86 x_mark_dec = torch.zeros(B, args.pred_len, 4).to(x.device)
#
# KeyboardInterrupt:
